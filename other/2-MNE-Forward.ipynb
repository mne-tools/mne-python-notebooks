# %% [markdown]
# Create a forward operator and display sensitivity maps
# ======================================================
#
# `
# Authors: Eric Larson <larson.eric.d@gmail.com>
#          Denis Engemann <denis.engemann@gmail.com>
#          Alex Gramfort <alexandre.gramfort@telecom-paristech.fr>
# `
#
# License: BSD (3-clause)

# %% [markdown]
# First setup some paths. We will use the MNE sample data.

# %%
import mne
from mne.datasets import sample
data_path = sample.data_path()


# the raw file containing the channel location + types
raw_fname = data_path + '/MEG/sample/sample_audvis_raw.fif'
# The transformation file obtained by coregistration
mri = data_path + '/MEG/sample/sample_audvis_raw-trans.fif'
# The source space obtained with
# mne_setup_source_space --ico -6
src = data_path + '/subjects/sample/bem/sample-oct-6-src.fif'
# The BEM file (LHS in Poission's equation...) obtained with
# mne_setup_forward_model --surf --ico 4
bem = data_path + '/subjects/sample/bem/sample-5120-5120-5120-bem-sol.fif'
# Name of the forward to read or compute
fwd_fname = data_path + '/MEG/sample/sample_audvis-meg-eeg-oct-6-fwd.fif'
# The paths to freesurfer reconstructions
subjects_dir = data_path + '/subjects'

# %%
from IPython.display import Image
from mayavi import mlab
# Out:
# WARNING:traits.has_traits:DEPRECATED: traits.has_traits.wrapped_class, 'the 'implements' class advisor has been deprecated. Use the 'provides' class decorator.

# %% [markdown]
# # Comppute Source Space and Morph to fsaverage

# %%
mne.set_log_level('WARNING')
print mne.grade_to_vertices('fsaverage', grade=5)[0].shape
# Out:
# (10242,)

# %%
# add_dist may give you a more accurate estimate of the surface normal
src_fsaverage = mne.setup_source_space('fsaverage', spacing='oct6', subjects_dir=subjects_dir, add_dist=False, overwrite=True)
src_sub = mne.morph_source_spaces(src_fsaverage, 'sample', subjects_dir=subjects_dir)
# mne.add_source_space_distances(src_sub, n_jobs=8)  # add cortical patch statstic

# %% [markdown]
# # Compute BEM solution

# %%
# can be done as follows, to save time we'll work with the precomputed one

# bem_model = mne.make_bem_model(subject='sample', subjects_dir=subjects_dir,
#                                conductivty=(0.3,))
# bem_solution = mne.make_bem_solution(bem_model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-a838bd055d6c> in <module>()
#       4
#       5 bem_model = mne.make_bem_model(subject='sample', subjects_dir=subjects_dir,
# ----> 6                                conductivty=(0.3,))
#       7 # bem_solution = mne.make_bem_solution(bem_model)
#
# TypeError: make_bem_model() got an unexpected keyword argument 'conductivty'

# %% [markdown]
# ## Are our bem meshes ok?

# %%
# %matplotlib inline
# mne.viz.plot_bem(subject='sample', subjects_dir=subjects_dir, orientation='axial');
mne.viz.plot_bem(subject='sample', subjects_dir=subjects_dir, orientation='coronal');

# %% [markdown]
# # Is our coregistration ok?

# %% [markdown]
# Compute the forward solution

# %%
info = mne.io.read_info(raw_fname)

fig = mne.viz.plot_trans(info, mri, subject='sample', dig=True, meg_sensors=True,
                         subjects_dir=subjects_dir);
mlab.savefig('coreg.jpg')
Image(filename='coreg.jpg', width=500)

# %%
fwd = mne.make_forward_solution(raw_fname, trans=mri, src=src_sub, bem=bem,
                                fname=None, # don't save it to disk
                                meg=True, # include MEG channels
                                eeg=True, # include EEG channels
                                mindist=5.0, # ignore sources <= 0mm from inner skull
                                n_jobs=8) # number of jobs to run in parallel

# %%
print fwd.keys()
# Out:
# ['info', 'sol_grad', 'nchan', 'src', 'source_nn', 'sol', 'source_rr', '_orig_sol_grad', 'surf_ori', 'coord_frame', 'source_ori', '_orig_sol', 'mri_head_t', 'nsource', '_orig_source_ori']

# %% [markdown]
# Convert to surface orientation for cortically constrained inverse modeling

# %%
fwd = mne.convert_forward_solution(fwd, surf_ori=True)
leadfield = fwd['sol']['data']
print "Leadfield size : %d sensors x %d dipoles" % leadfield.shape
# Out:
# Leadfield size : 366 sensors x 22302 dipoles

# %%
print fwd
# Out:
# <Forward | MEG channels: 305 | EEG channels: 59 | Source space: Surface with 8193 vertices | Source orientation: Free>

# %% [markdown]
# Or read it from disk

# %%
# fwd = mne.read_forward_solution(fwd_fname, surf_ori=True)

# %% [markdown]
# notebook inline plotting

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Compute sensitivity maps

# %%
grad_map = mne.sensitivity_map(fwd, ch_type='grad', mode='fixed')
mag_map = mne.sensitivity_map(fwd, ch_type='mag', mode='fixed')
eeg_map = mne.sensitivity_map(fwd, ch_type='eeg', mode='fixed')

# %% [markdown]
# # Show gain matrix a.k.a. leadfield matrix with sensitivy map

# %%
a = [1, 2, 3]
b = ['a', 'b', 'c']
zipped = zip(a, b)
print zipped
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %%
picks_meg = mne.pick_types(fwd['info'], meg=True, eeg=False)
picks_eeg = mne.pick_types(fwd['info'], meg=False, eeg=True)

fig, axes = plt.subplots(2, 1, figsize=(10, 8), sharex=True)  
fig.suptitle('Lead field matrix (500 dipoles only)', fontsize=14)

for ax, picks, ch_type in zip(axes, [picks_meg, picks_eeg], ['meg', 'eeg']):

   im = ax.imshow(leadfield[picks, :500], origin='lower', aspect='auto', cmap='RdBu_r')
   ax.set_title(ch_type.upper())
   ax.set_xlabel('sources')
   ax.set_ylabel('sensors')
   plt.colorbar(im, ax=ax, cmap='RdBu_r')

# %%
plt.hist([grad_map.data.ravel(), mag_map.data.ravel(), eeg_map.data.ravel()],
         bins=20, label=['Gradiometers', 'Magnetometers', 'EEG'], color=['c', 'b', 'k'])
plt.legend()
plt.title('Normal orientation sensitivity')
plt.xlabel('sensitivity')
plt.ylabel('count');

# %%
# enable correct backend for 3d plotting
# %matplotlib qt4
clim = dict(kind='percent', lims=(0.0, 50, 99), smoothing_steps=3)  # let's see single dipoles
# plot fsaverage morphed to brain
brain_subject = mag_map.plot(subject='sample', time_label='Magnetometer sensitivity',
                             subjects_dir=subjects_dir, clim=clim, smoothing_steps=2);
# Out:
# Updating smoothing matrix, be patient..
# INFO:surfer:Updating smoothing matrix, be patient..
# Smoothing matrix creation, step 1
# INFO:surfer:Smoothing matrix creation, step 1
# Smoothing matrix creation, step 2
# INFO:surfer:Smoothing matrix creation, step 2
# colormap: fmin=1.86e-02 fmid=4.29e-01 fmax=8.76e-01 transparent=1
# INFO:surfer:colormap: fmin=1.86e-02 fmid=4.29e-01 fmax=8.76e-01 transparent=1

# %%
view = 'lat'
brain.show_view(view)
brain.save_image('sensitivity_map_%s.jpg' % view)
Image(filename='sensitivity_map_%s.jpg' % view, width=400)

# %%
# map back to fsaveragr
eeg_map_fsaverage = eeg_map.to_original_src(src_fsaverage, subjects_dir=subjects_dir)

brain_fsaverage = eeg_map_fsaverage.plot(subject='fsaverage', time_label='Magnetometer sensitivity',
                                         subjects_dir=subjects_dir, clim=clim, smoothing_steps=2);

view = 'lat'
brain_fsaverage.show_view(view)
brain_fsaverage.save_image('sensitivity_map_%s.jpg' % view)
Image(filename='sensitivity_map_%s.jpg' % view, width=400)
# Out:
# Updating smoothing matrix, be patient..
# INFO:surfer:Updating smoothing matrix, be patient..
# Smoothing matrix creation, step 1
# INFO:surfer:Smoothing matrix creation, step 1
# Smoothing matrix creation, step 2
# INFO:surfer:Smoothing matrix creation, step 2
# colormap: fmin=1.63e-01 fmid=5.52e-01 fmax=8.47e-01 transparent=1
# INFO:surfer:colormap: fmin=1.63e-01 fmid=5.52e-01 fmax=8.47e-01 transparent=1

# %% [markdown]
# ## Exercise
#
# Plot the sensitivity maps for EEG and compare it with the MEG, can you justify the claims that:
#
# - MEG is not sensitive to radial sources
# - EEG is more sensitive to deep sources
#
# How will the MEG sensitivity maps and histograms change if you use a free instead if a fixed orientation?
#
# Try this changing the `mode` parameter in `mne.sensitivity_map` accordingly.
#
# Why don't we see any dipoles on the gyri?

# %% [markdown]
# # Visualizing field lines based on coregistration

# %%
# read in data

from mne import read_evokeds
from mne.datasets import sample
from mne import make_field_map

# data_path = sample.data_path()
data_path = '/media/libre/MNE-sample-data'

subjects_dir = data_path + '/subjects'
evoked_fname = data_path + '/MEG/sample/sample_audvis-ave.fif'
trans_fname = data_path + '/MEG/sample/sample_audvis_raw-trans.fif'

# %%
# If trans_fname is set to None then only MEG estimates can be visualized

condition = 'Left Auditory'
evoked = read_evokeds(evoked_fname, condition=condition, baseline=(-0.2, 0.0))

# Compute the field maps to project MEG and EEG data to MEG helmet
# and scalp surface
maps = make_field_map(evoked, trans=trans_fname, subject='sample',
                      subjects_dir=subjects_dir, n_jobs=1)

# explore several points in time
field_map = evoked.plot_field(maps, time=.1);

# %%
make_field_map?

# %%
from mayavi import mlab
mlab.savefig('field_map.jpg', figure=field_map)
from IPython.display import Image
Image(filename='field_map.jpg', width=800)
